# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,'g', lw=3)
plt.plot(x, z, 'y', lw=6)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(1,2)
plt.subplots_adjust(wspace=0.5)

ax1.plot(x,y,'g', lw=3)
ax1.set_title('LINEAR PLOT')   
ax1.set_xlabel('x')     
ax1.set_ylabel('2x')   

ax2.plot(x,z, 'y', lw=6)
ax2.set_title('SQUARED PLOT')
ax2.set_xlabel('x')
ax2.set_ylabel('squared x')

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(8,4))
plt.subplots_adjust(wspace=0.5)

ax1.plot(x,y,'g', lw=3)
ax1.set_title('LINEAR PLOT', fontweight = 'bold', fontsize = 18)   
ax1.set_xlabel('x')     
ax1.set_ylabel('2x')   

ax2.plot(x,z, 'y', lw=6)
ax2.set_title('SQUARED PLOT', fontname = 'Arial', fontweight = 'black', style = 'italic', fontsize = 10)
ax2.set_xlabel('x')
ax2.set_ylabel('squared x')

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
y = x**2
z = np.exp(x)

fig, ax1 = plt.subplots(figsize=(8,4))

ax1.set_xlabel('x')     
ax1.set_ylabel('squared x')   
ax1.plot(x, y, 'g', lw=3, label='label ax1')


ax2 = ax1.twinx()
ax2.plot(x, z, 'y', lw=6, label = 'label ax2')
ax2.set_ylabel('e ^ x')
ax2.set_yscale('log')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
fig.legend()

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# importing data
driver = 'mysql+pymysql'
ip = '34.65.10.136'
username = 'data-students'
password = 'iR0nH@cK-D4T4B4S3'
db = 'fitbit'
connection_string  = f'{driver}://{username}:{password}@{ip}/{db}'
engine = create_engine(connection_string)
query = 'SELECT * FROM fitbit2'
fitbit2 = pd.read_sql(query,engine)

# %%
fitbit2
# Out:
#            Date  Calorie burned  Steps Distance  Floors Minutes Sedentary  \
# 0    2015-05-08            1934    905     0.65       0             1.355
# 1    2015-05-09            3631  18925    14.11       4               611
# 2    2015-05-10            3204  14228    10.57       1               602
# 3    2015-05-11            2673   6756     5.02       8               749
# 4    2015-05-12            2495    502     3.73       1               876
# ..          ...             ...    ...      ...     ...               ...
# 362  2016-05-03            3796  18588    14.13      16               599
# 363  2016-05-04            3525  16382    12.39      16               684
# 364  2016-05-05            3649  21913     16.4      19               701
# 365  2016-05-06            3539  19023    14.79      15               575
# 366  2016-05-07             304   9526     7.08       2               564
#
#      Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(12,4))

by_months = fitbit2.groupby('Months_encoded').mean()
ax1.set_xlabel('Months')     
ax1.set_ylabel('Average Steps')   
ax1.plot(by_months.index, by_months['Steps'], 'b', lw=3)

# AVERAGE STEPS BY WORK_OR_WEEKEND

by_work = fitbit2.groupby('Work_or_Weekend').mean()
ax2.set_xlabel('Work or Weekend')     
ax2.set_ylabel('Average Steps')   
ax2.bar(by_work.index, by_work['Steps'], width = 0.2)
plt.xticks([0,1], ('Weekend', 'Work'))


plt.savefig('../figures/average_steps', dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None, metadata=None)
# Out:
# /usr/local/Cellar/ipython/7.7.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:21: MatplotlibDeprecationWarning:
# The frameon kwarg was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use facecolor instead.

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
minutes_list = ['Minutes Lightly Active', 'Minutes Very Active','Minutes Sedentary']

for elem in minutes_list:
    plt.scatter(fitbit2[elem], fitbit2['Steps'])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
driver = 'mysql+pymysql'
ip = '34.65.10.136'
username = 'data-students'
password = 'iR0nH@cK-D4T4B4S3'
db = 'titanic'
connection_string  = f'{driver}://{username}:{password}@{ip}/{db}'
engine = create_engine(connection_string)
query = 'SELECT * FROM titanic'
titanic = pd.read_sql(query,engine)

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
# PassengerId    1309 non-null int64
# Survived       891 non-null float64
# Pclass         1309 non-null int64
# Name           1309 non-null object
# Gender         1309 non-null object
# Age            1309 non-null float64
# SibSp          1309 non-null int64
# Parch          1309 non-null int64
# Ticket         1309 non-null object
# Fare           1309 non-null float64
# Cabin          1309 non-null object
# Embarked       1309 non-null object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=['int64', 'float64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6))
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age'], bins=80)
plt.xticks(np.arange(0, 90, step=10))
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, ax = plt.subplots(1, 3, figsize=(12,6))
plt.xticks(np.arange(0, 90, step=10))

ax[0].hist(titanic['Age'], bins=10)
ax[1].hist(titanic['Age'], bins=20)
ax[2].hist(titanic['Age'], bins=50)

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
As we group the elements, the final plot is less normal distributed as we use less bins
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.set()
sns.distplot(titanic['Age'], bins = 80)
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

gender = titanic.groupby(['Gender'], as_index = False).count()

fig, ax = plt.subplots(1, 1, figsize=(10,5))
plt.bar(gender['Gender'],gender['PassengerId'])
plt.xticks(np.arange(2),('female', 'male'))

plt.show()

# %%
# Method 2 - seaborn

sns.barplot(gender['Gender'],gender['PassengerId'])
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
pclass = titanic.groupby(['Pclass'], as_index = False).count()

sns.barplot(pclass['Pclass'], pclass['PassengerId'])
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(titanic["Age"], orient='v' )

# %%
"""
With a box plot we get the same information as if we use the method 'describe'
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
We can see the min, the max, the median, percentiles .25 and .75, the 'usual' min and max and the outliers
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,5))

sns.violinplot(titanic["Age"])

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
A comparison of quantities for each age, the wider is the diagram, the higher the quatity for that value
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

coef = np.polyfit(titanic['Age'],titanic['Fare'],1)
poly1d_fn = np.poly1d(coef) 

plt.plot(titanic['Age'],titanic['Fare'], 'bo', titanic['Age'], poly1d_fn(titanic['Age']), '-r')

# %%
# Method 2 - seaborn
sns.regplot(x='Age', y="Fare", data=titanic);

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
plt.figure(figsize=(10,8))

sns.heatmap(titanic.corr(),annot = True, cmap = 'YlGnBu')

plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Most correlated features are:
Pclass and Fare with - 0.56 in negative correlation
and
Parch and SibSp with positive 0.37 correlation
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
plt.figure(figsize=(10,5))

sns.boxplot(x=titanic["Pclass"],y=titanic['Age'])

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
plt.figure(figsize=(10,5))

a = sns.FacetGrid(titanic, col="Gender")
a.map(plt.hist, "Age")
