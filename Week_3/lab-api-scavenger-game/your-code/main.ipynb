# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import pandas as pd
import requests as rq

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here
username = 'guillemgodayol'
token = '276b0fc31914f41c6443b6139855c28727d6979b'
headers = {'Authorization': 'token ' + token}
forks = rq.get ('https://api.github.com/repos/ta-data-bcn/lab-api-scavenger-game/forks', headers = headers)

# %%
forks_df = pd.DataFrame(forks.json())

# %%
forks_df
# Out:
#            id                           node_id                    name  \
# 0   220932680  MDEwOlJlcG9zaXRvcnkyMjA5MzI2ODA=  lab-api-scavenger-game
# 1   220692854  MDEwOlJlcG9zaXRvcnkyMjA2OTI4NTQ=  lab-api-scavenger-game
# 2   220503371  MDEwOlJlcG9zaXRvcnkyMjA1MDMzNzE=  lab-api-scavenger-game
# 3   220491949  MDEwOlJlcG9zaXRvcnkyMjA0OTE5NDk=  lab-api-scavenger-game
# 4   220430147  MDEwOlJlcG9zaXRvcnkyMjA0MzAxNDc=  lab-api-scavenger-game
# 5   220290478  MDEwOlJlcG9zaXRvcnkyMjAyOTA0Nzg=  lab-api-scavenger-game
# 6   220273209  MDEwOlJlcG9zaXRvcnkyMjAyNzMyMDk=  lab-api-scavenger-game
# 7   220266304  MDEwOlJlcG9zaXRvcnkyMjAyNjYzMDQ=  lab-api-scavenger-game
# 8   220240318  MDEwOlJlcG9zaXRvcnkyMjAyNDAzMTg=  lab-api-scavenger-game
# 9   220217757  MDEwOlJlcG9zaXRvcnkyMjAyMTc3NTc=  lab-api-scavenger-game
# 10  220198065  MDEwOlJlcG9zaXRvcnkyMjAxOTgwNjU=  lab-api-scavenger-game
# 11  220165878  MDEwOlJlcG9zaXRvcnkyMjAxNjU4Nzg=  lab-api-scavenger-game
# ...

# %%
forks_df.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
forks_df['language']
# Out:
# 0                 None
# 1                 None
# 2                 None
# 3     Jupyter Notebook
# 4                 None
# 5                 None
# 6     Jupyter Notebook
# 7                 None
# 8                 None
# 9     Jupyter Notebook
# 10                None
# 11    Jupyter Notebook
# 12                None
# 13    Jupyter Notebook
# 14    Jupyter Notebook
# 15    Jupyter Notebook
# 16    Jupyter Notebook
# 17    Jupyter Notebook
# 18    Jupyter Notebook
# 19    Jupyter Notebook
# 20    Jupyter Notebook
# 21              Python
# 22              Python
# 23              Python
# 24              Python
# 25    Jupyter Notebook
# 26    Jupyter Notebook
# 27              Python
# 28              Python
# 29    Jupyter Notebook
# Name: language, dtype: object

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# Checking the unique values for 'language' column
languages = forks_df['language'].unique()

# %%
languages
# Out:
# array([None, 'Jupyter Notebook', 'Python'], dtype=object)

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here   repos/:owner/:repo/commits    
commits = rq.get ('https://api.github.com/repos/ta-data-bcn/lab-api-scavenger-game/commits', headers = headers, params = {'since' : '2019-09-01T00:00:00Z', 'until':'2019-10-01T00:00:00Z'})

# %%
commits_df = pd.DataFrame(commits.json())

# %%
commits_df
# Out:
#                                         sha  \
# 0  115655a4aa8067b6c0d533e5d4ccf5016ac56cb0
# 1  b24e84bd7ca04afc5dc6a224a1a064ed02588f4e
# 2  1dcf9464bb07f9766b07e2ab61c0bfbcfb1c2a67
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MTY5MTA4NjM5OjExNTY1NWE0YWE4MDY3Yj...
# 1  MDY6Q29tbWl0MTY5MTA4NjM5OmIyNGU4NGJkN2NhMDRhZm...
# 2  MDY6Q29tbWl0MTY5MTA4NjM5OjFkY2Y5NDY0YmIwN2Y5Nz...
#
#                                               commit  \
# 0  {'author': {'name': 'Eva Panizo', 'email': 'pa...
# 1  {'author': {'name': 'Nacho', 'email': 'nacho.0...
# 2  {'author': {'name': 'Nacho', 'email': 'nacho.0...
#
#                                                  url  \
# 0  https://api.github.com/repos/ta-data-bcn/lab-a...
# 1  https://api.github.com/repos/ta-data-bcn/lab-a...
# 2  https://api.github.com/repos/ta-data-bcn/lab-a...
#
#                                             html_url  \
# 0  https://github.com/ta-data-bcn/lab-api-scaveng...
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
secrets = rq.get ('https://api.github.com/search/code?q=scavengerhunt+repo:ironhack-datalabs/scavenger+in:path', headers = headers)

# %%
secrets.json()
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'url': 'https://api.github.com/repositories/162375181/contents/15024/.0006.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15024/.0006.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
# ...

# %%
secrets_df = pd.DataFrame(secrets.json()['items'])

# %%
secrets_df
# Out:
#                    name                       path  \
# 0   .0006.scavengerhunt  15024/.0006.scavengerhunt
# 1   .0014.scavengerhunt  49418/.0014.scavengerhunt
# 2   .0008.scavengerhunt  15534/.0008.scavengerhunt
# 3   .0017.scavengerhunt  70985/.0017.scavengerhunt
# 4   .0012.scavengerhunt  15534/.0012.scavengerhunt
# 5   .0007.scavengerhunt  17020/.0007.scavengerhunt
# 6   .0015.scavengerhunt  91701/.0015.scavengerhunt
# 7   .0021.scavengerhunt  30351/.0021.scavengerhunt
# 8   .0022.scavengerhunt  40303/.0022.scavengerhunt
# 9   .0005.scavengerhunt  44639/.0005.scavengerhunt
# 10  .0013.scavengerhunt  89338/.0013.scavengerhunt
# 11  .0018.scavengerhunt  45525/.0018.scavengerhunt
# 12  .0016.scavengerhunt  47222/.0016.scavengerhunt
# 13  .0009.scavengerhunt  97881/.0009.scavengerhunt
# 14  .0024.scavengerhunt  47222/.0024.scavengerhunt
# 15  .0010.scavengerhunt  47830/.0010.scavengerhunt
# 16  .0011.scavengerhunt  50896/.0011.scavengerhunt
# ...

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here
secrets_df.sort_values('name', inplace = True)

# %%
secrets_df
# Out:
#                    name                       path  \
# 23  .0001.scavengerhunt  98750/.0001.scavengerhunt
# 22  .0002.scavengerhunt  88596/.0002.scavengerhunt
# 19  .0003.scavengerhunt  60224/.0003.scavengerhunt
# 20  .0004.scavengerhunt  68848/.0004.scavengerhunt
# 9   .0005.scavengerhunt  44639/.0005.scavengerhunt
# 0   .0006.scavengerhunt  15024/.0006.scavengerhunt
# 5   .0007.scavengerhunt  17020/.0007.scavengerhunt
# 2   .0008.scavengerhunt  15534/.0008.scavengerhunt
# 13  .0009.scavengerhunt  97881/.0009.scavengerhunt
# 15  .0010.scavengerhunt  47830/.0010.scavengerhunt
# 16  .0011.scavengerhunt  50896/.0011.scavengerhunt
# 4   .0012.scavengerhunt  15534/.0012.scavengerhunt
# 10  .0013.scavengerhunt  89338/.0013.scavengerhunt
# 1   .0014.scavengerhunt  49418/.0014.scavengerhunt
# 6   .0015.scavengerhunt  91701/.0015.scavengerhunt
# 12  .0016.scavengerhunt  47222/.0016.scavengerhunt
# 3   .0017.scavengerhunt  70985/.0017.scavengerhunt
# ...

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# First I check one request 
headers2 = {'Accept':'application/vnd.github.v3.raw'}

first_path = rq.get ('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/.0001.scavengerhunt', headers = headers2)

# %%
first_path.text
# Out:
# 'In\n'

# %%
# As we get just the content, we can loop over all the paths and put the text into a list
content = []
for path in secrets_df['path']:
    text = rq.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/'+path, headers = headers2)
    content.append(text.text)

# %%
content
# Out:
# ['In\n',
#  'data\n',
#  'science,\n',
#  '80\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'spent\n',
#  'is\n',
#  'preparing\n',
#  'data,\n',
#  '20\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'is\n',
#  'spent\n',
#  'complaining\n',
#  'about\n',
#  'the\n',
#  'need\n',
#  'to\n',
#  'prepare\n',
#  'data.\n']

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here
joke = ' '.join(content)

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
print(joke)
# Out:
# In
#  data
#  science,
#  80
#  percent
#  of
#  time
#  spent
#  is
#  preparing
#  data,
#  20
#  percent
#  of
#  time
#  is
#  spent
#  complaining
#  about
#  the
#  need
#  to
#  prepare
#  data.
